# %%
import pandas as pd
from draw_plots import PlotDrawing
from PIL import Image

# Считываем JSON-файл в pandas DataFrame
data = pd.read_json("deviation.json")

# Создаем экземпляр класса PlotDrawing
plot_drawing = PlotDrawing()

# Вызываем функцию draw_plots и получаем пути к графикам
plot_paths = plot_drawing.draw_plots(data)

# Визуализируем графики
for path in plot_paths:
    display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x432>
